# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('C++_Introduction.txt',encoding="utf-8")
text_data =loader.load()
print(text_data[0])
# Out:
# page_content='C++  Introduction
# The C++ programming language provides a model of memory and computation that closely matches that of most computers. In addition, it provides powerful and flexible mechanisms for abstraction; that is, language constructs that allow the programmer to introduce and use new types of objects that match the concepts of an application. Thus, C++ supports styles of programming that rely on fairly direct manipulation of hardware resources to deliver a high degree of efficiency plus higher-level styles of programming that rely on user-defined types to provide a model of data and computation that is closer to a human’s view of the task being performed by a computer. These higher-level styles of programming are often called data abstraction, object-oriented programming, and generic programming.
# C++ History
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("PAYMENT SUCCESSFUL 3RD SEM.pdf")
documents =  loader.load()
print(documents[0])
# Out:
# page_content='Online Payment Receipt
# Transaction Reference No 13PS7SXFG0ZE0W4
# Payment Gateway Reference ZUR32149062462
# Transaction Status SUCCESSFUL
# Student Name Vedant Jagdish Jiwanapurkar
# Student Details Batch : 2023 2027 Roll No : 69
# Fee Category FEES
# Paid For
# Transaction Amount Rs. 23969.0
# Timestamp Jul 09,2024 8:34:23 AM
# 7/10/24, 8:35 AM Payment Successful
# https://erp.mgsnagpur.org/bdreturn7.json 1/1' metadata={'producer': 'Skia/PDF m126', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36', 'creationdate': '2024-07-10T03:05:18+00:00', 'title': 'Payment Successful', 'moddate': '2024-07-10T03:05:18+00:00', 'source': 'PAYMENT SUCCESSFUL 3RD SEM.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %%
from langchain_community.document_loaders import WebBaseLoader

# Pass URL inside a list
urls = ["https://help4code.com/"
        "https://github.com/Vedantjiw/Langchain-chatbot"
        "https://bbycroft.net/llm"
        "https://www.instaiq.in/"]
loader = WebBaseLoader(urls)
docs = loader.load()

print(docs)
# Out:
# [Document(metadata={'source': 'https://help4code.com/https://github.com/Vedantjiw/Langchain-chatbothttps://bbycroft.net/llmhttps://www.instaiq.in/', 'title': 'A potentially dangerous Request.Path value was detected from the client (:).', 'language': 'No language found.'}, page_content="\n\n\nA potentially dangerous Request.Path value was detected from the client (:).\n\n\n\n\nServer Error in '/' Application.\n A potentially dangerous Request.Path value was detected from the client (:). \n\n Description: An unhandled exception occurred during the execution of the current web request. Please review the stack trace for more information about the error and where it originated in the code.\r\n\r\n            \n Exception Details: System.Web.HttpException: A potentially dangerous Request.Path value was detected from the client (:).\nSource Error: \n\n\n\n\r\n\r\nAn unhandled exception was generated during the execution of the current web request. Information regarding the origin and locati
# ...

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader(file_path="C:/Users/vedan/Downloads/annual-enterprise-survey-2024-financial-year-provisional.csv")
csv_data= loader.load()
csv_data
# Out:
# [Document(metadata={'source': 'C:/Users/vedan/Downloads/annual-enterprise-survey-2024-financial-year-provisional.csv', 'row': 0}, page_content='Year: 2024\nIndustry_aggregation_NZSIOC: Level 1\nIndustry_code_NZSIOC: 99999\nIndustry_name_NZSIOC: All industries\nUnits: Dollars (millions)\nVariable_code: H01\nVariable_name: Total income\nVariable_category: Financial performance\nValue: 979594\nIndustry_code_ANZSIC06: ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'),
# ...
